# %%
from django_for_jupyter import init_django
init_django("arches")

import json
import pprint 
import uuid

import pandas as pd
from lxml import etree
from collections import OrderedDict

import base64
from IPython.display import Image, display
import matplotlib.pyplot as plt

from arches.app.utils.data_management.resource_graphs.exporter import get_graphs_for_export as get_graph
from arches.app.utils.data_management.resource_graphs.exporter import create_mapping_configuration_file as get_mapping
from arches.app.utils.data_management.resource_graphs.exporter import export as export_gephi


from django.core.serializers.json import DjangoJSONEncoder

dataset_uuid = "af04eac2-a131-11ed-a102-9cf387da2c40"

#dataset_uuid = "b36ccfad-0686-4213-9511-1481b86a9e21" # Dataset

# %%
def get_graph_as_json(_uuid):
    gr = get_graph([_uuid])
    return json.dumps(gr['graph'], indent=2, cls=DjangoJSONEncoder)

_graph = get_graph_as_json("b36ccfad-0686-4213-9511-1481b86a9e21")
#print(_graph)

# %%
def get_graph_as_json(_uuid):
    _graph = get_graph([_uuid])
    return _graph

def make_cards_df(graph):
    c_df = pd.DataFrame(graph['graph'][0]['cards']).sort_values(by=['sortorder'])
    for idx, row in c_df.iterrows():
        c_df.loc[idx, 'cardid'] = str(row['cardid'])
    c_df.to_csv('exporter/out/01_cards.csv', index=False)
    return c_df

def make_edges_df(graph):
    df = pd.DataFrame(graph['graph'][0]['edges'])
    df.to_csv('exporter/out/02_edges.csv', index=False)
    return df 

def make_nodes_df(graph):
    df = pd.DataFrame(graph['graph'][0]['nodes'])
    df.to_csv('exporter/out/03_nodes.csv', index=False)
    return df

def make_xx_df(graph):
    df = pd.DataFrame(graph['graph'][0]['cards_x_nodes_x_widgets'])        
    for idx, row in df.iterrows():
        df.loc[idx, 'sortorder'] = str(row['sortorder']).replace('.0', '')
    df.to_csv('exporter/out/04_xx.csv', index=False)
    return df
                    
# ---------------------------
def add_edges_to_nodes(edges, nodes):
    
    for n_idx, n_row in nodes.iterrows():
        n_node_id = str(n_row['nodeid'])        
        n_name = str(n_row['name'])        
        for e_idx, e_row in edges.iterrows():
            e_domainnode_id = str(e_row['domainnode_id'])
            e_rangenode_id = str(e_row['rangenode_id'])
            if e_rangenode_id == n_node_id:  
                nodes.loc[n_idx, 'domainnode_id'] = e_domainnode_id
                nodes.loc[n_idx, 'rangenode_id'] = e_rangenode_id
                nodes.loc[n_idx, 'edgeid'] = str(e_row['edgeid'])
                #nodes.loc[e_idx, 'ontologyproperty'] = str(e_row['ontologyproperty'])                    
                
                # add parents                
                parent = nodes.loc[nodes['nodeid'] == e_domainnode_id]['name'].values.tolist()[0]
                nodes.loc[n_idx, 'parent'] = parent
                parent = ''
    nodes.to_csv('exporter/out/05_nodes_edges.csv', index=False)
    return nodes

def add_cards_to_nodes_edges(cards, node_edges):
    
    for n_idx, n_row in node_edges.iterrows():
        n_nodegroup_id = str(n_row['nodegroup_id'])
        n_name = str(n_row['name'])
        for c_idx, c_row in cards_df.iterrows():
            c_nodegroup_id = str(c_row['nodegroup_id'])
            c_name = str(c_row['name']['en'])
            if n_nodegroup_id == c_nodegroup_id:
                    node_edges.loc[n_idx, 'card_id'] = str(c_row['cardid'])
                    
                    
                    #
                    #
                    #
                    #node_edges.loc[n_idx, 'node_card_sortorder'] = str(c_row['sortorder']).replace('.0', '')
                    node_edges.loc[n_idx, 'node_card_sortorder'] = int(c_row['sortorder'])
                    #
                    #
                    #
                    #
                    
                    # add the rest that's needed
                    node_edges.loc[n_idx, 'instructions'] = str(c_row['instructions'])
                    node_edges.loc[n_idx, 'helptitle'] = str(c_row['helptitle'])
                    node_edges.loc[n_idx, 'helptext'] = str(c_row['helptext'])
                    node_edges.loc[n_idx, 'visible'] = str(c_row['visible'])

                    
        if pd.isnull(node_edges.loc[n_idx, 'parent']):
            node_edges.loc[n_idx, 'parent'] = 'root'
            node_edges.loc[n_idx, 'node_card_sortorder'] = 0
            node_edges.loc[n_idx, 'domainnode_id'] = 'RDF'
            #node_edges.loc[n_idx, 'domainnode_id'] = str(n_row['nodeid'])
            node_edges.loc[n_idx, 'rangenode_id'] = str(n_row['nodeid'])

    node_edges['node_card_sortorder'] = node_edges['node_card_sortorder'].astype('int')        
    node_edges.to_csv('exporter/out/06_nodes_edges_cards.csv', index=False)
    return node_edges

def add_xx_to_nodes_edges_cards(xx, edges_node_cards):
    
    for e_idx, e_row in edges_node_cards.iterrows():
        e_node_id = str(e_row['nodeid'])
        for x_idx, x_row in xx.iterrows():
            x_node_id = str(x_row['node_id'])
            if e_node_id == x_node_id:
                edges_node_cards.loc[e_idx, 'card_sortorder'] = str(x_row['sortorder'])
            
    edges_node_cards.to_csv('exporter/out/07_nodes_edges_cards_xx.csv', index=False)
    return edges_node_cards


# ---------------------------


ONTOLOGY_NAMESPACES = {
    #'http://my_namespace_here/': 'some_ns',
    "http://www.w3.org/1999/02/22-rdf-syntax-ns#": "RDF",
    "http://www.w3.org/2001/XMLSchema#": "xsd",
    "http://www.w3.org/2000/01/rdf-schema#": "rdfs",
    "http://www.cidoc-crm.org/cidoc-crm/": "crm",
    "http://www.ics.forth.gr/isl/CRMarchaeo/": "CRMarchaeo",
    "http://www.ics.forth.gr/isl/CRMdig/": "CRMdig",
    "http://www.ics.forth.gr/isl/CRMgeo/": "CRMgeo",
    "http://www.ics.forth.gr/isl/CRMinf/": "CRMinf",
    "http://www.ics.forth.gr/isl/CRMsci/": "CRMsci",
    "http://parthenos.d4science.org/CRMext/CRMpe.rdfs/": "CRMpe",
    "https://takin.solutions/ontologies/CRMsurv/": "CRMsurv"
}



def add_namespace_suffix(graph):

    def make_namespace_suffix(url):
        if '#' in url:
            url_split = url.split('#')
            class_prop = url_split[-1:][0]
            namespace_prefix = url_split[0] + '#'
        else:
            url_split = url.split('/')
            class_prop = url_split[-1:][0]
            namespace_prefix = '/'.join(url_split[:-1]) + '/'
        namespace = ONTOLOGY_NAMESPACES.get(namespace_prefix)    
        return '%s:%s' % (namespace, class_prop)

    for idx, row in graph.iterrows():
        graph.loc[idx, 'sip_property'] = make_namespace_suffix(row['parentproperty'])
        if row['parent'] == 'root':
            graph.loc[idx, 'sip_property'] = 'RDF'
            graph.loc[idx, 'sip_class'] = make_namespace_suffix(row['ontologyclass'])
        else:    
            graph.loc[idx, 'sip_class'] = make_namespace_suffix(row['ontologyclass'])
                
    graph.to_csv('exporter/out/08_graph_ns.csv', index=False)
    return graph


def build_paths(graph):

    graph = graph.sort_values(by=['node_card_sortorder', 'card_sortorder', 'parent'])
    
    path_list = []
    path_dict = []
    parents = set()
    children = {}

    for idx, row in graph.iterrows():
        children[row['rangenode_id']] = row['domainnode_id']
            
    def ancestors(p):
        return (ancestors(children[p]) if p in children else []) + [p]

    for k in (set(children.keys())):
        path_list.append(ancestors(k))
        
    for idx, row in graph.iterrows():
        node_id = str(row['nodeid'])
        
        for path in path_list:
            if node_id == path[-1]:                
                graph.loc[idx, 'path'] = str(path)
                graph.loc[idx, 'path_length'] = str(len(path))
        if row['domainnode_id'] == 'RDF':
            graph.loc[idx, 'domainnode_id'] = None
            graph.loc[idx, 'rangenode_id'] = str(row['nodeid'])    

    
    graph.to_csv('exporter/out/09_graph_path.csv', index=False)            
    return graph            
                

def make_ns_paths(graph):
    
    path_list = []
    path_dict = {}
    doc_paths = []
        
    path_df = graph[['nodeid', 'path']]
    path_list = []
    path_dict = {}
    doc_path = []
        
    for p_idx, p_row in path_df.iterrows():
        paths = p_row['path'].strip('][').replace("'", "").split(', ')           
        for item in paths:
            if item != 'RDF':
                path_row = graph.loc[graph['nodeid'] == item]
                _property = path_row['sip_property'].values.tolist()[0]
                _class = path_row['sip_class'].values.tolist()[0]
                path_list.append(str(_property))
                path_list.append(str(_class))
                _name = path_row['name'].values.tolist()[0]
        
        path_dict = {"nodeid": p_row['nodeid'], "name": _name, "path": path_list}
        path_list = []
        doc_paths.append(path_dict)
        path_dict = {}

    for idx, row in graph.iterrows():
        for item in doc_paths:            
            if row['nodeid'] == item['nodeid']:
#                print(json.dumps(item, indent=2))
#                print('_-')
                graph.loc[idx, 'ns_path'] = [item]

    doc_paths = []
    graph = graph.sort_values(by=['node_card_sortorder', 'path_length', 'card_sortorder', 'parent'])
    graph.to_csv('exporter/out/10_graph_ns_path.csv', index=False)    
    return graph

# %%
graph = get_graph_as_json(dataset_uuid)

edges_df = make_edges_df(graph)
nodes_df = make_nodes_df(graph)
cards_df = make_cards_df(graph)
xx_df = make_xx_df(graph)

node_edges_df = add_edges_to_nodes(edges_df, nodes_df)
node_edges_cards_df = add_cards_to_nodes_edges(cards_df, node_edges_df)
node_edges_cards_xx_df = add_xx_to_nodes_edges_cards(xx_df, node_edges_cards_df)

graph_ns = add_namespace_suffix(node_edges_cards_xx_df)
graph_path = build_paths(graph_ns)

graph = make_ns_paths(graph_path)

print('done')
# Out:
# done

# %%
def make_doc_paths(ns_graph):
    
    doc_dict = {}
    doc_list = []

    for idx, row in ns_graph.iterrows():        
        node_id = row['nodeid']
        
        # For some weird reason the first row stores ns_path as dict, not list
        if isinstance(row['ns_path'], dict):
            ns_path = row['ns_path']
        elif isinstance(row['ns_path'], list):   
            ns_path = row['ns_path'][0]

        name = row['name']
        parent = row['parent']
        node_card_sortorder = row['node_card_sortorder']
        description = row['description']
        datatype = row['datatype']
        isrequired = row['isrequired']
        isvisible = "" if pd.isna(ns_graph.loc[idx, 'visible']) else row['visible']
        instructions = "" if pd.isna(ns_graph.loc[idx, 'instructions']) else row['instructions']
        helptitle = "" if pd.isna(ns_graph.loc[idx, 'helptitle']) else row['helptitle']
        helptext = "" if pd.isna(ns_graph.loc[idx, 'helptext']) else row['helptext']
        
        doc_dict = {"nodeid": node_id, "path": ns_path['path'], "name": name, "parent": parent, "node_card_sortorder": node_card_sortorder,
                    "datatype": datatype, "isrequired": isrequired, "isvisible": isvisible, "description": description,
                    "instructions": instructions, "helptitle": helptitle, "helptext": helptext, 
                    "relation": {name: parent}, 'datatype': datatype}
                    
        doc_list.append(doc_dict)
        ns_graph.loc[idx, 'doc_path'] = [doc_dict]
        doc_dict = {}
    
    ns_graph.to_csv('exporter/out/20_graph_nsa_path.csv', index=False)        
    return doc_list

print('done')
# Out:
# done

# %% [markdown]
# ## Make rec_defs

# %%
def make_rec_defs(_graph):
    
  
    nodes = make_doc_paths(_graph)

    item_list = []
    children = {} #OrderedDict()
    
    for item in nodes:
        #print(item['path'])
        children[item['name']] = item['parent']
            
    for node in nodes:
        def tree(p):
            return (tree(children[p]) if p in children else []) + [p]
        #print(list(node['relation'])[0])
        _tree = tree(list(node['relation'])[0])        
        _tag = node['path'][-1]
        
        if len(_tree) == 2:
            root = etree.Element("root", tag="RDF") 
            node_map = etree.SubElement(root, "node-mapping", inputPath="/input")
            elem2 = etree.SubElement(root, "elem", tag = _tag)
            attr = etree.SubElement(elem2, "attr", uriCheck="True", tag = "rdf:about")                   
        elif len(_tree) == 3:
            elem3 = etree.SubElement(elem2, "elem", tag = _tag, label = node['name'], nodeid= node['nodeid'], isrequired = str(node['isrequired']), isvisible = str(node['isvisible']))
            if node['datatype'] == 'resource-instance':
                elem3.attrib['uriCheck']= 'True'
                elem3.attrib['attrs']= 'rdf:resource'
            if node['datatype'] == 'semantic':
                elem3.attrib['unmappable']= 'True'        
        elif len(_tree) == 4:
            elem4 = etree.SubElement(elem3, "elem", tag = _tag, label = node['name'], nodeid= node['nodeid'], isrequired = str(node['isrequired']), isvisible = str(node['isvisible']))
            if node['datatype'] == 'semantic':
                elem4.attrib['unmappable']= 'True'
        elif len(_tree) == 5:
            elem5 = etree.SubElement(elem4, "elem", tag = _tag, label = node['name'], nodeid= node['nodeid'], isrequired = str(node['isrequired']), isvisible = str(node['isvisible']))
            if node['datatype'] == 'semantic':
                elem5.attrib['unmappable']= 'True'
        elif len(_tree) == 6:
            elem6 = etree.SubElement(elem5, "elem", tag = _tag, label = node['name'], nodeid= node['nodeid'], isrequired = str(node['isrequired']), isvisible = str(node['isvisible']))
            if node['datatype'] == 'semantic':
                elem6.attrib['unmappable']= 'True'
        elif len(_tree) == 7:
            elem7 = etree.SubElement(elem6, "elem", tag = _tag, label = node['name'], nodeid= node['nodeid'], isrequired = str(node['isrequired']), isvisible = str(node['isvisible']))
            if node['datatype'] == 'semantic':
                elem7.attrib['unmappable']= 'True'
        elif len(_tree) == 8:
            elem8 = etree.SubElement(elem7, "elem", tag = _tag, label = node['name'], nodeid= node['nodeid'], isrequired = str(node['isrequired']), isvisible = str(node['isvisible']))
            if node['datatype'] == 'semantic':
                elem8.attrib['unmappable']= 'True'
        else:
            pass
        
        
    return etree.tostring(root, encoding='utf-8', method='xml', pretty_print=True).decode() 

# TMP for checking things
#import ast
#generic = lambda x: ast.literal_eval(x)
#conv = {'ns_path': generic}
#tmp_graph = pd.read_csv('exporter/out/10_graph_ns_path.csv', converters=conv)    

rec_def = make_rec_defs(graph)
#rec_def = make_rec_defs(graph)
print(rec_def)
# Out:
# <root tag="RDF">
#   <node-mapping inputPath="/input"/>
#   <elem tag="CRMsurv:U4_Survey_Surface_Unit">
#     <attr uriCheck="True" tag="rdf:about"/>
#     <elem tag="crm:E42_Identifier" label="Identification" nodeid="1d7c1e80-a132-11ed-a102-9cf387da2c40" isrequired="True" isvisible="True" unmappable="True">
#       <elem tag="crm:E55_Type" label="Unit identifier Type" nodeid="5799bffa-a132-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#       <elem tag="xsd:string" label="Unit identifier" nodeid="3755377e-a132-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#     </elem>
#     <elem tag="CRMsurv:U3_Survey_Process_Unit" label="Survey Process Unit" nodeid="02eab194-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#       <elem tag="None:S9_Property_Type" label="Observed Object Types" nodeid="02eab66c-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True"/>
#       <elem tag="crm:E55_Type" label="Survey Technique" nodeid="02eab6f8-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True"/>
#       <elem tag="crm:E54_Dimension" label="Quantification_ADD_COLLECTION" nodeid="02eab9b4-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True"/>
#       <elem tag="crm:E33_Linguistic_Object" label="Recorded by" nodeid="02eabacc-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True"/>
#       <elem tag="crm:PC14_carried_out_by" label="Process Unit Surveyour" nodeid="02eabb58-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#         <elem tag="crm:E21_Person" label="Participant" nodeid="02eabbda-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True"/>
#         <elem tag="crm:E55_Type" label="Participant's Role" nodeid="02eabc66-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True"/>
#         <elem tag="crm:E65_Creation" label="Creator" nodeid="02eab504-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#           <elem tag="crm:E21_Person" label="Survey Unit Recorded By" nodeid="02eaba36-a24a-11ed-a3a2-9cf387da2c40" isrequired="False" isvisible="True"/>
#         </elem>
#       </elem>
#     </elem>
#     <elem tag="crm:E33_Linguistic_Object" label="Unit notes" nodeid="07065d32-a13c-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#       <elem tag="xsd:string" label="Unit note" nodeid="169d66fa-a13c-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#     </elem>
#     <elem tag="CRMsurv:U2_Survey_Collection_Activity" label="Surveyours" nodeid="5bcc4112-a13a-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#       <elem tag="CRMsurv:U1_Archaeological_Survey" label="Survey" nodeid="c2b40484-a142-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#         <elem tag="crm:PC14_carried_out_by" label="Surveyour" nodeid="d2b20278-a142-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#           <elem tag="crm:E21_Person" label="Survey Activity Carried Out By" nodeid="e29571de-a142-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E55_Type" label="Survey Activity Role" nodeid="67e4b200-a143-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#         </elem>
#       </elem>
#     </elem>
#     <elem tag="crm:E27_Site" label="Site" nodeid="4ca46e0c-a13b-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" uriCheck="True" attrs="rdf:resource"/>
#     <elem tag="rdfs:Literal" label="Survey Unit Coordinates File" nodeid="1d49b360-a13b-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#     <elem tag="CRMgeo:SP6_Declarative_Place" label="Place Coordinates" nodeid="446a88ce-a13c-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#       <elem tag="CRMgeo:SP5_Geometric_Place_Expression" label="Place" nodeid="a1fcc24c-a13f-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#         <elem tag="crm:E33_E41_Linguistic_Appellation" label="Survey Unit Coordinate" nodeid="2c84a63c-a140-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#         <elem tag="crm:E33_Linguistic_Object" label="Place Coordinates Statement" nodeid="31684d64-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#         <elem tag="CRMgeo:SP4_Spatial_Coordinate_Reference_System" label="Survey Unit Coordinate System" nodeid="fcf6277e-a13f-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#           <elem tag="crm:E33_Linguistic_Object" label="Source Reference Work for Statement" nodeid="3168507a-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E55_Type" label="Statement Type" nodeid="316851ba-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="xsd:string" label="Timespan Statement" nodeid="316852d2-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E56_Language" label="Collection Statement Language" nodeid="3168546c-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E55_Type" label="Statement Confidentiality" nodeid="316855d4-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E33_E41_Linguistic_Appellation" label="Collection Statement Timespan Name" nodeid="31685692-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="xsd:string" label="Statement Label" nodeid="31685746-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E55_Type" label="Survey Unit Coordinate Type" nodeid="542c7d36-a140-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#             <elem tag="crm:E55_Type" label="Statement Confidentiality AAT Type" nodeid="316853ae-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="crm:E55_Type" label="Statement Type AAT Type" nodeid="31685520-b2c7-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           </elem>
#         </elem>
#       </elem>
#     </elem>
#     <elem tag="CRMsurv:U4_Survey_Surface_Unit" label="Survey Unit Part" nodeid="93da1790-a13b-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" uriCheck="True" attrs="rdf:resource"/>
#     <elem tag="crm:E55_Type" label="Survey Unit Type" nodeid="945a4720-a132-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#     <elem tag="crm:E54_Dimension" label="Dimension" nodeid="f53328f8-a139-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True">
#       <elem tag="rdfs:Literal" label="Visibility" nodeid="0691b86c-a13a-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True"/>
#       <elem tag="crm:E55_Type" label="Type of measurement scale" nodeid="1c064744-a13a-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True"/>
#       <elem tag="crm:E58_Measurement_Unit" label="Unit of the measurement scale" nodeid="36c7c0c6-a13a-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True"/>
#     </elem>
#     <elem tag="CRMdig:D1_Digital_Object" label="Digital Reference" nodeid="8bdf963c-a140-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" unmappable="True"/>
#     <elem tag="crm:E53_Place" label="Survey Unit Place" nodeid="a8d0f36c-a13b-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" uriCheck="True" attrs="rdf:resource"/>
#     <elem tag="crm:E36_Visual_Item" label="Survey Unit Image" nodeid="c0313d96-a13b-11ed-a102-9cf387da2c40" isrequired="False" isvisible="True" uriCheck="True" attrs="rdf:resource"/>
#     <elem tag="CRMsurv:U3_Survey_Process_Unit" label="Survey Collections" nodeid="9b045fbc-b289-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True" unmappable="True">
#       <elem tag="CRMsurv:U2_Survey_Collection_Activity" label="Survey Collection Activity" nodeid="c389da52-b289-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True" unmappable="True">
#         <elem tag="CRMsurv:U6_Material_Sample" label="Survey Collection" nodeid="e66168ec-b289-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True">
#           <elem tag="crm:E55_Type" label="Survey Collection Type" nodeid="28696cf8-b28a-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#           <elem tag="crm:E54_Dimension" label="Survey Collection  Dimension" nodeid="a25d1f60-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True" unmappable="True">
#             <elem tag="rdfs:Literal" label="Highest Possible Dimension Value" nodeid="a25d2398-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="crm:E33_E41_Linguistic_Appellation" label="Name for Dimension" nodeid="a25d24a6-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="rdfs:Literal" label="Dimension Value" nodeid="a25d2564-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True" unmappable="True"/>
#             <elem tag="crm:E58_Measurement_Unit" label="Dimension Unit" nodeid="a25d2618-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="xsd:string" label="Dimension Label" nodeid="a25d26c2-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="crm:E33_Linguistic_Object" label="Source Reference Work for Dimension" nodeid="a25d2776-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="crm:E55_Type" label="Dimension Type" nodeid="a25d2816-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="rdfs:Literal" label="Lowest Possible Dimension Value" nodeid="a25d28c0-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True"/>
#             <elem tag="crm:E13_Attribute_Assignment" label="Dimension Data Assignment" nodeid="a25d296a-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True" unmappable="True"/>
#             <elem tag="crm:E33_Linguistic_Object" label="Statement about Dimension" nodeid="a25d2a14-b2c5-11ed-8ee6-96a6d245525a" isrequired="False" isvisible="True" unmappable="True"/>
#           </elem>
#         </elem>
#       </elem>
#     </elem>
#   </elem>
# </root>

# %% [markdown]
# ## Make documentation

# %%
def make_docs_xml(_graph):
        
    doc_list = make_doc_paths(_graph)    
    item_list = []
    root = etree.Element("docs")
    for item in doc_list:            
        doc_path = '/'.join(item['path'])
        doc = etree.SubElement(root, "doc", nodeid = item['nodeid'], path = doc_path)  
        para = etree.SubElement(doc, "para", name= "Label") 
        para.text = item['name']
        para = etree.SubElement(doc, "para", name= "Description") 
        para.text = str(item['description'])
        para = etree.SubElement(doc, "para", name= "Instructions") 
        para.text = str(item['instructions'])
        para = etree.SubElement(doc, "para", name= "Helptitle") 
        para.text = str(item['helptitle'])
        para = etree.SubElement(doc, "para", name= "Helptext") 
        para.text = str(item['helptitle'])
        para = etree.SubElement(doc, "para", name= "Datatype") 
        para.text = str(item['datatype'])
        para = etree.SubElement(doc, "para", name= "Required") 
        para.text = str(item['isrequired'])
        
    item_doc = etree.tostring(root, encoding='utf-8', method='xml', pretty_print=True).decode()        
    return item_doc    

docss = make_docs_xml(graph)
print(docss)
# Out:
# <docs>
#   <doc nodeid="af04e702-a131-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit">
#     <para name="Label">SEM.1_Survey Unit</para>
#     <para name="Description"></para>
#     <para name="Instructions"></para>
#     <para name="Helptitle"></para>
#     <para name="Helptext"></para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="1d7c1e80-a132-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P1_is_identified_by/crm:E42_Identifier">
#     <para name="Label">Identification</para>
#     <para name="Description">Airtable Description: This field is used to record the type of the identifier attributed to the documented entity.&lt;/para&gt;</para>
#     <para name="Instructions">{'en': 'Is this eg numeric, text, ...?'}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">True</para>
#   </doc>
#   <doc nodeid="5799bffa-a132-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P1_is_identified_by/crm:E42_Identifier/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Unit identifier Type</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': 'Is this eg numeric, text, ...?'}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="3755377e-a132-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P1_is_identified_by/crm:E42_Identifier/crm:P190_has_symbolic_content/xsd:string">
#     <para name="Label">Unit identifier</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': 'Is this eg numeric, text, ...?'}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eab194-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit">
#     <para name="Label">Survey Process Unit</para>
#     <para name="Description"></para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eab66c-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/None:O9_observed_property_type/None:S9_Property_Type">
#     <para name="Label">Observed Object Types</para>
#     <para name="Description">Survey Artifacts Type</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eab6f8-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P32_used_general_technique/crm:E55_Type">
#     <para name="Label">Survey Technique</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eab9b4-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/None:O16_observed_value/crm:E54_Dimension">
#     <para name="Label">Quantification_ADD_COLLECTION</para>
#     <para name="Description">Survey Artifacts Dimension</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eabacc-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object">
#     <para name="Label">Recorded by</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eabb58-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P01i_is_domain_of/crm:PC14_carried_out_by">
#     <para name="Label">Process Unit Surveyour</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eabbda-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P01i_is_domain_of/crm:PC14_carried_out_by/crm:P02_has_range/crm:E21_Person">
#     <para name="Label">Participant</para>
#     <para name="Description">Surveyor</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eabc66-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P01i_is_domain_of/crm:PC14_carried_out_by/crm:P14.1_in_the_role_of/crm:E55_Type">
#     <para name="Label">Participant's Role</para>
#     <para name="Description">Surveyor Role</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eab504-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P94i_was_created_by/crm:E65_Creation">
#     <para name="Label">Creator</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="02eaba36-a24a-11ed-a3a2-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P94i_was_created_by/crm:E65_Creation/crm:P14_carried_out_by/crm:E21_Person">
#     <para name="Label">Survey Unit Recorded By</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="07065d32-a13c-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object">
#     <para name="Label">Unit notes</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="169d66fa-a13c-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P190_has_symbolic_content/xsd:string">
#     <para name="Label">Unit note</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="5bcc4112-a13a-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P12i_was_present_at/CRMsurv:U2_Survey_Collection_Activity">
#     <para name="Label">Surveyours</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="c2b40484-a142-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P12i_was_present_at/CRMsurv:U2_Survey_Collection_Activity/crm:P9i_forms_part_of/CRMsurv:U1_Archaeological_Survey">
#     <para name="Label">Survey</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="d2b20278-a142-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P12i_was_present_at/CRMsurv:U2_Survey_Collection_Activity/crm:P9i_forms_part_of/CRMsurv:U1_Archaeological_Survey/crm:P01i_is_domain_of/crm:PC14_carried_out_by">
#     <para name="Label">Surveyour</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="e29571de-a142-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P12i_was_present_at/CRMsurv:U2_Survey_Collection_Activity/crm:P9i_forms_part_of/CRMsurv:U1_Archaeological_Survey/crm:P01i_is_domain_of/crm:PC14_carried_out_by/crm:P02_has_range/crm:E21_Person">
#     <para name="Label">Survey Activity Carried Out By</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="67e4b200-a143-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P12i_was_present_at/CRMsurv:U2_Survey_Collection_Activity/crm:P9i_forms_part_of/CRMsurv:U1_Archaeological_Survey/crm:P01i_is_domain_of/crm:PC14_carried_out_by/crm:P14.1_in_the_role_of/crm:E55_Type">
#     <para name="Label">Survey Activity Role</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="4ca46e0c-a13b-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P89_falls_within/crm:E27_Site">
#     <para name="Label">Site</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="1d49b360-a13b-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P168_place_is_defined_by/rdfs:Literal">
#     <para name="Label">Survey Unit Coordinates File</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="446a88ce-a13c-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place">
#     <para name="Label">Place Coordinates</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a1fcc24c-a13f-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression">
#     <para name="Label">Place</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="2c84a63c-a140-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P1_is_identified_by/crm:E33_E41_Linguistic_Appellation">
#     <para name="Label">Survey Unit Coordinate</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="31684d64-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object">
#     <para name="Label">Place Coordinates Statement</para>
#     <para name="Description"></para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="fcf6277e-a13f-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/CRMgeo:Q9_is_expressed_in_terms_of/CRMgeo:SP4_Spatial_Coordinate_Reference_System">
#     <para name="Label">Survey Unit Coordinate System</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="3168507a-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object">
#     <para name="Label">Source Reference Work for Statement</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="316851ba-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Statement Type</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="316852d2-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P190_has_symbolic_content/xsd:string">
#     <para name="Label">Timespan Statement</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="3168546c-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P72_has_language/crm:E56_Language">
#     <para name="Label">Collection Statement Language</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="316855d4-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Statement Confidentiality</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="31685692-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P1_is_identified_by/crm:E33_E41_Linguistic_Appellation">
#     <para name="Label">Collection Statement Timespan Name</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="31685746-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/rdfs:label/xsd:string">
#     <para name="Label">Statement Label</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="542c7d36-a140-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P1_is_identified_by/crm:E33_E41_Linguistic_Appellation/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Survey Unit Coordinate Type</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="316853ae-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P2_has_type/crm:E55_Type/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Statement Confidentiality AAT Type</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="31685520-b2c7-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMgeo:Q11i_is_approximated_by/CRMgeo:SP6_Declarative_Place/CRMgeo:Q10i_place_is_defined_by/CRMgeo:SP5_Geometric_Place_Expression/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object/crm:P2_has_type/crm:E55_Type/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Statement Type AAT Type</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="93da1790-a13b-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P89_falls_within/CRMsurv:U4_Survey_Surface_Unit">
#     <para name="Label">Survey Unit Part</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="945a4720-a132-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Survey Unit Type</para>
#     <para name="Description"></para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="f53328f8-a139-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P43_has_dimension/crm:E54_Dimension">
#     <para name="Label">Dimension</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="0691b86c-a13a-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P43_has_dimension/crm:E54_Dimension/crm:P90_has_value/rdfs:Literal">
#     <para name="Label">Visibility</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="1c064744-a13a-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P43_has_dimension/crm:E54_Dimension/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Type of measurement scale</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="36c7c0c6-a13a-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P43_has_dimension/crm:E54_Dimension/crm:P91_has_unit/crm:E58_Measurement_Unit">
#     <para name="Label">Unit of the measurement scale</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="8bdf963c-a140-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P67i_is_referred_to_by/CRMdig:D1_Digital_Object">
#     <para name="Label">Digital Reference</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a8d0f36c-a13b-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P89_falls_within/crm:E53_Place">
#     <para name="Label">Survey Unit Place</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="c0313d96-a13b-11ed-a102-9cf387da2c40" path="RDF/CRMsurv:U4_Survey_Surface_Unit/crm:P138i_has_representation/crm:E36_Visual_Item">
#     <para name="Label">Survey Unit Image</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="9b045fbc-b289-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit">
#     <para name="Label">Survey Collections</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="c389da52-b289-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity">
#     <para name="Label">Survey Collection Activity</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="e66168ec-b289-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample">
#     <para name="Label">Survey Collection</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="28696cf8-b28a-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Survey Collection Type</para>
#     <para name="Description">None</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d1f60-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension">
#     <para name="Label">Survey Collection  Dimension</para>
#     <para name="Description"></para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d2398-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P90b_has_upper_value_limit/rdfs:Literal">
#     <para name="Label">Highest Possible Dimension Value</para>
#     <para name="Description">LAF.98
# Highest Possible Dimension Value
# This field is used to record the highest possible value for a dimension when the value of the dimension is known as a range.
# -&gt;p43-&gt;E54[98_1]-&gt;p90b-&gt;rdf:literal</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d24a6-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P1_is_identified_by/crm:E33_E41_Linguistic_Appellation">
#     <para name="Label">Name for Dimension</para>
#     <para name="Description">LAF.100
# Name for Dimension
# This field is used to link the documented dimension to a name that has been attributed to it.
# -&gt;p43-&gt;E54[98_1]-&gt;p1-&gt;E33_41[100_1]</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d2564-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P90_has_value/rdfs:Literal">
#     <para name="Label">Dimension Value</para>
#     <para name="Description">LAF.101
# Dimension Value
# This field is used to record the value for the documented instance of dimension.	-
# &gt;p43-&gt;E54[98_1]-&gt;p90-&gt;rdf:literal</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d2618-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P91_has_unit/crm:E58_Measurement_Unit">
#     <para name="Label">Dimension Unit</para>
#     <para name="Description">LAF.99
# Dimension Unit
# This field is used to record the unit for the documented instance of dimension.
# -&gt;p43-&gt;E54[98_1]-&gt;p91-&gt;E58[99_1]</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">number</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d26c2-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/rdfs:label/xsd:string">
#     <para name="Label">Dimension Label</para>
#     <para name="Description">LAF.102
# Dimension Label
# This field is used to record the string value of the machine readable label used for the documented dimension.
# -&gt;p43-&gt;E54[98_1]-&gt;rdfs:label-&gt;rdf:literal</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d2776-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object">
#     <para name="Label">Source Reference Work for Dimension</para>
#     <para name="Description">LAF.103
# Source Reference Work for Dimension
# This field is used to link the documented dimension to a statement that describes it.
# -&gt;p43-&gt;E54[98_1]-&gt;p67i-&gt;E33[103_1]</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">resource-instance</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d2816-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P2_has_type/crm:E55_Type">
#     <para name="Label">Dimension Type</para>
#     <para name="Description">LAF.104
# Dimension Type
# This field is used to record the formal type of the documented dimension.
# -&gt;p43-&gt;E54[98_1]-&gt;p2-&gt;E55[104_1]</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">concept</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d28c0-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P90_has_value/rdfs:Literal">
#     <para name="Label">Lowest Possible Dimension Value</para>
#     <para name="Description">LAF.105
# Lowest Possible Dimension Value
# This field is used to record the lowest possible value for a dimension when the value of the dimension is known as a range.
# -&gt;p43-&gt;E54[98_1]-&gt;p90a-&gt;rdf:literal</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">string</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d296a-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P141i_was_assigned_by/crm:E13_Attribute_Assignment">
#     <para name="Label">Dimension Data Assignment</para>
#     <para name="Description">LAF.435
# Dimension Data Assignment
# This field is used to indicate the details of the data assignment of this dimension to the documented object.
# -&gt;p43-&gt;E54[98_1]-&gt;p141i-&gt;E13[435_1]</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
#   <doc nodeid="a25d2a14-b2c5-11ed-8ee6-96a6d245525a" path="RDF/CRMsurv:U4_Survey_Surface_Unit/CRMsurv:UP2i_was_surveyed_by/CRMsurv:U3_Survey_Process_Unit/crm:P9_consists_of/CRMsurv:U2_Survey_Collection_Activity/CRMsurv:UP3_collected/CRMsurv:U6_Material_Sample/crm:P43_has_dimension/crm:E54_Dimension/crm:P67i_is_referred_to_by/crm:E33_Linguistic_Object">
#     <para name="Label">Statement about Dimension</para>
#     <para name="Description">LAF.453
# Statement about Dimension
# This field is used to link the dimension of a documented entity to a statement that describes it.
# -&gt;p43-&gt;E54[98_1]-&gt;P67i-&gt;E33[453_1]</para>
#     <para name="Instructions">{'en': ''}</para>
#     <para name="Helptitle">{'en': ''}</para>
#     <para name="Helptext">{'en': ''}</para>
#     <para name="Datatype">semantic</para>
#     <para name="Required">False</para>
#   </doc>
# </docs>

# %% [markdown]
# ## Make Opts

# %%
def make_opts(graph, concepts):
    
    ns_list = make_doc_paths(graph)
    root = etree.Element("opts")    
    for item in ns_list:
        opt_path = item['path']
        
        
        #
        # NOT OK, just a name matching at the moment. It needs to be matched against UUIDs since dictionary and displayName can be different.
        # Not avialble in the built in concept export so pull directly from the database
        # Use just one language! 
        #   <opt value="Anmerkung"/>
        #   <opt value="annotaties"/>
        #   <opt value="annotations"/>
        
        for k,v in json.loads(concepts).items():
            if item['name'] == k:
            
                opt_path = '/'.join(item['path'])
                opt_list = etree.SubElement(root, "opt-list", dictionary=item['name'], path=opt_path, displayName=item['name'])  
                for _opt in v.values():
                    opt = etree.SubElement(opt_list, "opt", value=_opt)

    _opts = etree.tostring(root, encoding='utf-8', method='xml', pretty_print=True).decode()        
    print(_opts)


def get_concepts_as_json(_uuid):
    concept_file = get_mapping(_uuid)
    return [concept_file[0]['outputfile'].getvalue()]

_concepts = get_concepts_as_json(dataset_uuid)
#_graph = pd.read_csv('mapper/out/10_graph_ns_path.csv', dtype={'sip_path':str })

print(_concepts[0])

#all_opts = make_opts(graph, _concepts[0])
#print(all_opts)
# Out:
# {
#     "Collection Statement Language": "Collection Statement Language does not appear to be configured with a valid concept collectionid",
#     "Dimension Type": "Dimension Type does not appear to be configured with a valid concept collectionid",
#     "Observed Object Types": "Observed Object Types does not appear to be configured with a valid concept collectionid",
#     "Participant's Role": "Participant's Role does not appear to be configured with a valid concept collectionid",
#     "Quantification_ADD_COLLECTION": "Quantification_ADD_COLLECTION does not appear to be configured with a valid concept collectionid",
#     "Statement Confidentiality": "Statement Confidentiality does not appear to be configured with a valid concept collectionid",
#     "Statement Confidentiality AAT Type": "Statement Confidentiality AAT Type does not appear to be configured with a valid concept collectionid",
#     "Statement Type": "Statement Type does not appear to be configured with a valid concept collectionid",
#     "Statement Type AAT Type": "Statement Type AAT Type does not appear to be configured with a valid concept collectionid",
#     "Survey Activity Role": "Survey Activity Role does not appear to be configured with a valid concept collectionid",
#     "Survey Collection Type": "Survey Collection Type does not appear to be configured with a valid concept collectionid",
#     "Survey Technique": "Survey Technique does not appear to be configured with a valid concept collectionid",
#     "Survey Unit Type": "Survey Unit Type does not appear to be configured with a valid concept collectionid",
#     "Unit identifier Type": "Unit identifier Type does not appear to be configured with a valid concept collectionid",
#     "Resource to Resource Relationship Types": {
#         "ac41d9be-79db-4256-b368-2f4559cfbe55": "is related to"
#     }
# }

# %% [markdown]
# ## Make mermaid graph

# %%
#A[Square Rect] -- Link text --> B((Circle))

def make_graph(graph):
    
    def render_graph(m_str):
        graphbytes = m_str.encode("ascii")
        base64_bytes = base64.b64encode(graphbytes)
        base64_string = base64_bytes.decode("ascii")
        display(Image(url="https://mermaid.ink/img/" + base64_string))
    
    m_list = []
    g_list = make_doc_paths(graph)
    #print(json.dumps(g_list, indent=2))
    m_list.append('graph LR;')
    
    for item in g_list:        
        for k, v in item['relation'].items():
            if v != 'root':
                m_list.append('%s--> %s;' % (v.replace(' ', '_'), k.replace(' ', '_')))
    
    render_graph('\n'.join(m_list))                   
    
mermaid_graph = make_graph(graph)    
#mermaid_graph = render_graph(n_graph)
# Out:
# <img src="https://mermaid...."/>
