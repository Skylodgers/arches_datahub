# %%
import csv
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, SKOS, DCTERMS, DC
import uuid
#from django.core.serializers.json import DjangoJSONEncoder
from functools import reduce

NS = Namespace("")

# %%
file = 'rdm/source/rdm_new.csv'
#concept_uri;parent;label;comment;aat_identifier;;parent_tw
voc_name = 'Datahub'
voc_uri = 'https://data.antwerp.be/id/term/Datahub'

# %%
g = Graph()
g.bind("ns", NS)
g.bind("skos", SKOS)
g.bind("dcterms", DCTERMS)
g.bind("dc", DC)
    
with open(f'source/{file}', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=';')
    next(reader, None)  # skip the headers
    ns_voc_name = NS[voc_name]
    ns_voc_uri = NS[voc_uri]
    g.add((ns_voc_uri, RDF.type, SKOS['ConceptScheme']))
    g.add((ns_voc_uri, DCTERMS.title, Literal(voc_name,lang="nl")))
    for row in reader:
        #uri = NS[str(row[0])]
        uri = NS[f'https://localhost:8000/{uuid.uuid5(uuid.NAMESPACE_DNS, row[0])}']
        parent_uri = NS[str(row[1])]
        g.add((uri, RDF.type, SKOS.Concept))
        g.add((uri, SKOS.prefLabel, Literal(row[2], lang="nl")))
        g.add((uri, SKOS.inScheme, ns_voc_uri))
        uri_str = f'https://data.antwerp.qq/##€€id€€:€€{str(uuid.uuid5(uuid.NAMESPACE_DNS, row[0]))}€€,€€value€€:€€{row[0]}**'            
        g.add((uri, DCTERMS.identifier, NS[uri_str]))
        
        
        if str(row[1]) == 'https://data.antwerp.be/id/term/Datahub':
            g.add((ns_voc_uri, SKOS.hasTopConcept, uri))
        else:    
            g.add((parent_uri, SKOS.narrower, uri))

        if len(str(row[3])) > 0:
           g.add((uri, SKOS.editorialNote, Literal(row[3], lang="nl")))
        if len(str(row[4])) > 0:
            aat_uri_str = f'https://data.antwerp.qq/##€€id€€:€€{str(uuid.uuid5(uuid.NAMESPACE_DNS, row[4]))}€€,€€value€€:€€{row[4]}**'            
            g.add((uri, DCTERMS.identifier, NS[aat_uri_str]))

skos_data = g.serialize(format='pretty-xml').decode('utf-8')

def replace_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text

d = {"https://data.antwerp.qq/": "", "##": "{", "**": "}", "€€": "\"", "\"{": "{", "}\"": "}"}

skos_cleaned = replace_all(skos_data, d)

with open(f'out/{voc_name}_out_test.xml', "w") as f:
    f.write(skos_cleaned)
    
print(skos_cleaned)
skos_data = ''
del g
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:skos="http://www.w3.org/2004/02/skos/core#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#   xmlns:dcterms="http://purl.org/dc/terms/"
# >
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/brocade-catalog/obj-sg">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e17f8c37-fe3c-536a-b7dc-8cd0e5fecc9e">
#         <skos:prefLabel xml:lang="nl">Gift Orde van Advocaten van Antwerpen</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"e17f8c37-fe3c-536a-b7dc-8cd0e5fecc9e","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-adv}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/a3c41a4c-e9e1-54a3-85ac-f5d75ad40d34">
#         <skos:prefLabel xml:lang="nl">Reinaertcollectie Wim Gielen</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"a3c41a4c-e9e1-54a3-85ac-f5d75ad40d34","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-wgr}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/a79176b3-8b20-5ad8-970d-f13e6d4030d2">
#         <skos:prefLabel xml:lang="nl">Bibliotheek Rederijkerskamer De Goudbloem-Broedermin (Antwerpen)</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"a79176b3-8b20-5ad8-970d-f13e6d4030d2","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-rga}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e8612ea5-fbe7-5c52-bf83-ed3a1ee5a602">
#         <dcterms:identifier rdf:resource={"id":"e8612ea5-fbe7-5c52-bf83-ed3a1ee5a602","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hvt}/>
#         <skos:prefLabel xml:lang="nl">Fonds Hendrik van Tichelen</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/ddaacbab-6f1c-5594-b196-b587d22ac8c6">
#         <dcterms:identifier rdf:resource={"id":"ddaacbab-6f1c-5594-b196-b587d22ac8c6","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-wil}/>
#         <skos:prefLabel xml:lang="nl">Collectie over Sint Willibrordus</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/72d91f1e-7372-5607-869e-1e1b6a518982">
#         <dcterms:identifier rdf:resource={"id":"72d91f1e-7372-5607-869e-1e1b6a518982","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-lc}/>
#         <skos:prefLabel xml:lang="nl">Fonds Lode Craeybeckx</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7402b065-ad0d-5f43-a321-19e8fdc785ec">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Fonds G. Schamelhout</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"7402b065-ad0d-5f43-a321-19e8fdc785ec","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-gs}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/bdbe4209-cbd9-5f57-8f87-c97baf91895e">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Schenking Tone Brulin</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"bdbe4209-cbd9-5f57-8f87-c97baf91895e","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-tb}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/101e3233-781b-5d9b-8fb7-ea1c317a02ff">
#         <dcterms:identifier rdf:resource={"id":"101e3233-781b-5d9b-8fb7-ea1c317a02ff","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-wilx}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie over Sint Willibrordus - doublet</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/2ab638bf-6fa1-5684-aed2-64464dc4b80b">
#         <skos:prefLabel xml:lang="nl">Depot Heemkunde Vlaanderen</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"2ab638bf-6fa1-5684-aed2-64464dc4b80b","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hv}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/82ab21ce-6e52-5888-870c-f632b5d5ddc1">
#         <skos:prefLabel xml:lang="nl">Collectie van Joseph De Lange</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"82ab21ce-6e52-5888-870c-f632b5d5ddc1","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jdl}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/d8a5d25e-2fe5-5243-aef4-c8d95d0bf7de">
#         <skos:prefLabel xml:lang="nl">Collectie liturgica van de Sint-Jacobskerk [Antwerpen]</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"d8a5d25e-2fe5-5243-aef4-c8d95d0bf7de","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jac}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/3f7d58e2-2f6d-534a-80cd-0c53cfc78238">
#         <dcterms:identifier rdf:resource={"id":"3f7d58e2-2f6d-534a-80cd-0c53cfc78238","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jvr}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie Jan Van Roey</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/511c89eb-4716-5d6b-8923-b15990f50d30">
#         <dcterms:identifier rdf:resource={"id":"511c89eb-4716-5d6b-8923-b15990f50d30","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jvh}/>
#         <skos:prefLabel xml:lang="nl">Bibliotheek Jos Vanhecke</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/9a090ca5-cdaa-5d22-84b2-5b0d3c3c414d">
#         <dcterms:identifier rdf:resource={"id":"9a090ca5-cdaa-5d22-84b2-5b0d3c3c414d","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-biografieppr}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">RUB Biografie Peter Paul Rubens</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/6f047192-8727-548a-bebd-40c43be8a2d7">
#         <dcterms:identifier rdf:resource={"id":"6f047192-8727-548a-bebd-40c43be8a2d7","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hlx}/>
#         <skos:prefLabel xml:lang="nl">Bibliotheek Hubert Lampo - doubletten</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/ede654bd-3564-564c-91c5-e1e87453f5ac">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"ede654bd-3564-564c-91c5-e1e87453f5ac","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mpm-bh}/>
#         <skos:prefLabel xml:lang="nl">Max Horn-bibliotheek</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/a3f1798d-0eee-5bf2-b465-01314a124450">
#         <skos:prefLabel xml:lang="nl">Collectie Albert Van Roey</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"a3f1798d-0eee-5bf2-b465-01314a124450","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-avr}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/c37afa9d-11c2-5f1b-a512-5617da8ab632">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"c37afa9d-11c2-5f1b-a512-5617da8ab632","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-hercklouis}/>
#         <skos:prefLabel xml:lang="nl">Collectie Louis Van Herck</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7f47d985-0b24-571b-8f7d-e57ab6724add">
#         <dcterms:identifier rdf:resource={"id":"7f47d985-0b24-571b-8f7d-e57ab6724add","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-feb}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie van de Vlaamse Esperantobond (Flandra Esperanto-Biblioteko, [Antwerpen])</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/963f0125-6916-5571-8ef7-26b778d32c87">
#         <skos:prefLabel xml:lang="nl">Fonds F. van Hoof</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"963f0125-6916-5571-8ef7-26b778d32c87","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-fvh}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/b93563f7-f98d-5968-921f-affda04bad01">
#         <skos:prefLabel xml:lang="nl">Hebreeuwse drukken in MPM</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"b93563f7-f98d-5968-921f-affda04bad01","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mpm-hebr}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/25919746-8b6e-5604-9a11-9b7fa305fedf">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"25919746-8b6e-5604-9a11-9b7fa305fedf","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-imcfx}/>
#         <skos:prefLabel xml:lang="nl">Collectie doubletten van Ivo Michiels en Christiane Faes</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/0ad52307-870b-5d79-9a91-2f96663ed454">
#         <skos:prefLabel xml:lang="nl">Fonds Ger Schmook</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"0ad52307-870b-5d79-9a91-2f96663ed454","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-gss}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/8e464d5c-00dc-5f10-a47c-ab61cdfa0198">
#         <dcterms:identifier rdf:resource={"id":"8e464d5c-00dc-5f10-a47c-ab61cdfa0198","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-kub}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Kunstenaarsboeken</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/f82ef114-8ac8-5bd7-a52f-069cc586cdba">
#         <dcterms:identifier rdf:resource={"id":"f82ef114-8ac8-5bd7-a52f-069cc586cdba","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-zpa}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Overdracht Zilvermuseum Sterckshof Provincie Antwerpen</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/63b7e9b9-1e5a-5969-a775-d81337a71401">
#         <dcterms:identifier rdf:resource={"id":"63b7e9b9-1e5a-5969-a775-d81337a71401","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-bam}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Bibliotheek AngÃ¨le Manteau</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/07079ee7-dc0b-5724-8573-457c9f197773">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"07079ee7-dc0b-5724-8573-457c9f197773","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ncj}/>
#         <skos:prefLabel xml:lang="nl">Fonds Nationaal Centrum voor Jeugdliteratuur - Stichting Lezen - Iedereen Leest</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/848ba970-a1a2-5213-89db-cb7cdb0b32e6">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"848ba970-a1a2-5213-89db-cb7cdb0b32e6","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-kmda}/>
#         <skos:prefLabel xml:lang="nl">Bruikleen Koninklijke Maatschappij voor Dierkunde van Antwerpen</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/c2fe9c0b-76de-55ff-96dd-8ab115bb3545">
#         <skos:prefLabel xml:lang="nl">Schenking Frederik Nottebohm</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"c2fe9c0b-76de-55ff-96dd-8ab115bb3545","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-fn}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/23d882b1-e3ed-5671-942a-05f61e422871">
#         <skos:prefLabel xml:lang="nl">Fonds Hugo van Kuyck</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"23d882b1-e3ed-5671-942a-05f61e422871","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hvk}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/baf9439d-d3a3-5146-a571-71b757244f34">
#         <dcterms:identifier rdf:resource={"id":"baf9439d-d3a3-5146-a571-71b757244f34","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mmb-hb}/>
#         <skos:prefLabel xml:lang="nl">Historische Bibliotheek</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/019c69cf-c96d-55ec-b17f-5be578e1edca">
#         <dcterms:identifier rdf:resource={"id":"019c69cf-c96d-55ec-b17f-5be578e1edca","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-dhulst}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie R.-A. D'Hulst</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/29e6dfb2-55ab-5bd9-84e2-3fe534b1363e">
#         <dcterms:identifier rdf:resource={"id":"29e6dfb2-55ab-5bd9-84e2-3fe534b1363e","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-pn}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie Paul Neuhuys</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/b4cfa50b-ca48-553a-b612-d44516384509">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie van Konstantijn Simillion</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"b4cfa50b-ca48-553a-b612-d44516384509","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ks}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/aa1a6f30-cc69-5298-92cf-22011271f235">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Uit de bibliotheek van het Nationaal Scheepvaartmuseum</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"aa1a6f30-cc69-5298-92cf-22011271f235","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mas-nsm}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/a08cad02-0d72-5305-a862-bb6d3fb1718f">
#         <dcterms:identifier rdf:resource={"id":"eb56ec30-af7b-5ded-9b7b-0f3eff7aa61e","value":"http://vocab.getty.edu/aat/300379012}/>
#         <dcterms:identifier rdf:resource={"id":"a08cad02-0d72-5305-a862-bb6d3fb1718f","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jm}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Niet gekend (ehc-jm)</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/97fd55e7-e5d0-582e-84a4-404d4c548c71">
#         <dcterms:identifier rdf:resource={"id":"97fd55e7-e5d0-582e-84a4-404d4c548c71","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ap-kc-hti}/>
#         <skos:prefLabel xml:lang="nl">Bibliotheek van het Departement D - Herman Teirlinck Instituut</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/87f3a2dd-94ee-55f6-ac8a-8112845e7ceb">
#         <skos:prefLabel xml:lang="nl">Fonds Ger Schmook jr.</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"87f3a2dd-94ee-55f6-ac8a-8112845e7ceb","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-gsj}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/311848c1-438a-5be7-ba7f-56ab80884bd6">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"311848c1-438a-5be7-ba7f-56ab80884bd6","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hbtd}/>
#         <skos:prefLabel xml:lang="nl">Schenking Havenbedrijf</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/f2a8df80-ed2d-5277-bdc4-46ee72ac53bf">
#         <skos:prefLabel xml:lang="nl">Collectie liturgica van de O.-L.-Vrouwkathedraal [Antwerpen]</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"f2a8df80-ed2d-5277-bdc4-46ee72ac53bf","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-kat}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/dd27b973-70ca-50f4-812f-52f1492262a2">
#         <skos:prefLabel xml:lang="nl">Catalogus Miraeus, 1609</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"dd27b973-70ca-50f4-812f-52f1492262a2","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-mir}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/06f52ac7-16f8-585e-8978-13e9cd3aecca">
#         <skos:prefLabel xml:lang="nl">Stedelijke Technische Leergangen voor Bibliotheekwezen van Antwerpen</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"06f52ac7-16f8-585e-8978-13e9cd3aecca","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-stlbw}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/0d25ba9b-9056-5770-9383-a31151c08998">
#         <skos:prefLabel xml:lang="nl">Fonds A.H. Cornette</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"0d25ba9b-9056-5770-9383-a31151c08998","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ac}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/65300259-74a6-5e9c-a492-3aacee0abc4f">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Gift Bestendig Dotatiefonds</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"65300259-74a6-5e9c-a492-3aacee0abc4f","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-g}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/643b5e02-dba5-5b44-81d4-6a611af228b0">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Uit de bibliotheek van het Volkskundemuseum</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"643b5e02-dba5-5b44-81d4-6a611af228b0","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mas-vm}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/5d22dafa-3cfb-5dfa-abce-7232a9874475">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie Van Hemeldonck</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"5d22dafa-3cfb-5dfa-abce-7232a9874475","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-vanhemeldonck}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/cea32fef-8df5-5818-9582-055fe8ef67d2">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"cea32fef-8df5-5818-9582-055fe8ef67d2","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hfj}/>
#         <skos:prefLabel xml:lang="nl">Collectie van Henri Floris Jespers</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/4e129e6a-eee0-532d-a818-1c19652daf50">
#         <skos:prefLabel xml:lang="nl">Collectie van Herwig Verleyen</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"4e129e6a-eee0-532d-a818-1c19652daf50","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hvb}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/cd301bb7-5bf8-58bf-a6bd-621a4e6b3f9d">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"cd301bb7-5bf8-58bf-a6bd-621a4e6b3f9d","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-depp}/>
#         <skos:prefLabel xml:lang="nl">Depot Uitgeverij P</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e5ca10f6-c8db-572c-b615-8818f522d014">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie Faculteit Historische Pedagogiek (UGent)</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"e5ca10f6-c8db-572c-b615-8818f522d014","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-fhp}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/508a90d6-34fa-51ee-821a-05e89e1a3aa3">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"508a90d6-34fa-51ee-821a-05e89e1a3aa3","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mpm-havre}/>
#         <skos:prefLabel xml:lang="nl">Aankopen veiling Gustave van Havre</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/004c055e-4d8d-5c85-9cc3-be12de3111ba">
#         <dcterms:identifier rdf:resource={"id":"004c055e-4d8d-5c85-9cc3-be12de3111ba","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-csu}/>
#         <skos:prefLabel xml:lang="nl">Collectie Strips Standaard Uitgeverij</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7cfa38b6-9f8d-5e3d-a3f5-0a3b851eef7c">
#         <dcterms:identifier rdf:resource={"id":"7cfa38b6-9f8d-5e3d-a3f5-0a3b851eef7c","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-voe}/>
#         <skos:prefLabel xml:lang="nl">Depot Stichting Voetnoot</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/bcf8a2fd-56f8-5c35-9d99-1f293831ae4b">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"bcf8a2fd-56f8-5c35-9d99-1f293831ae4b","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-efv}/>
#         <skos:prefLabel xml:lang="nl">Collectie van de Vlaamse Esperantobond (Esperanto-FondaÄµo C. Vanbiervliet, [Kortrijk])</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/60da6c57-c01c-5170-8834-4db3efbca8b4">
#         <skos:prefLabel xml:lang="nl">Fonds Maurits Bilcke</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"60da6c57-c01c-5170-8834-4db3efbca8b4","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-mb}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/3644f345-12ec-50dc-81e2-5f7dabc24cfa">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"3644f345-12ec-50dc-81e2-5f7dabc24cfa","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-vml}/>
#         <skos:prefLabel xml:lang="nl">Volkskundemuseum Antwerpen. Collectie volksmuziek</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/6da1986e-50b3-5e49-a2d4-864c2acac8ba">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"6da1986e-50b3-5e49-a2d4-864c2acac8ba","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-dbnl}/>
#         <skos:prefLabel xml:lang="nl">DBNL-digitaliseringsproject</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/91bb017c-100d-5b38-ac37-ba0ab8d94891">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"91bb017c-100d-5b38-ac37-ba0ab8d94891","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mpm-plantkunde}/>
#         <skos:prefLabel xml:lang="nl">Botanische oude drukken</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7353e3ed-c296-5894-9195-6da3cca255b3">
#         <dcterms:identifier rdf:resource={"id":"7353e3ed-c296-5894-9195-6da3cca255b3","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-mg}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Fonds Maurice Gilliams</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/5b66fa8b-a1a1-5f56-a84a-deb231d9906d">
#         <dcterms:identifier rdf:resource={"id":"5b66fa8b-a1a1-5f56-a84a-deb231d9906d","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-wco}/>
#         <skos:prefLabel xml:lang="nl">Collectie van Willy Courteaux</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/31485348-64be-5b72-97e4-21039f417a01">
#         <skos:prefLabel xml:lang="nl">Collectie van Society of Friends, Ede</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"31485348-64be-5b72-97e4-21039f417a01","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-sfe}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/f6d81e62-fe1f-5532-9065-0657455526af">
#         <dcterms:identifier rdf:resource={"id":"f6d81e62-fe1f-5532-9065-0657455526af","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jh}/>
#         <skos:prefLabel xml:lang="nl">Fonds Joseph Hendel</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/9363bcd2-b90a-565c-af2d-2b4186c777a4">
#         <skos:prefLabel xml:lang="nl">Collectie Ludwig Burchard</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"9363bcd2-b90a-565c-af2d-2b4186c777a4","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-bur}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/1b4df1e9-2d0e-57f5-89fe-a9ea6853bb98">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Niet gekend (rub-print)</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"eb56ec30-af7b-5ded-9b7b-0f3eff7aa61e","value":"http://vocab.getty.edu/aat/300379012}/>
#         <dcterms:identifier rdf:resource={"id":"1b4df1e9-2d0e-57f5-89fe-a9ea6853bb98","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-print}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/064a9fb5-3136-573b-bca9-0c8056136928">
#         <skos:prefLabel xml:lang="nl">Bibliotheek Marnix Gijsen (Belgisch Consulaat, New York)</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"064a9fb5-3136-573b-bca9-0c8056136928","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-mgny}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/bde6c021-8a25-5df6-8d9f-65b200ffac9f">
#         <dcterms:identifier rdf:resource={"id":"bde6c021-8a25-5df6-8d9f-65b200ffac9f","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-google}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Google-digitaliseringsproject</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/958111df-bfe2-5332-9f80-6f0d969e7985">
#         <dcterms:identifier rdf:resource={"id":"958111df-bfe2-5332-9f80-6f0d969e7985","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-vbe}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie Vlaamse beweging</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/b7ba9e3d-06c7-5b74-b25f-706d40996249">
#         <skos:prefLabel xml:lang="nl">Collectie vlugschriften uit WOII</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"b7ba9e3d-06c7-5b74-b25f-706d40996249","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-vwo}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/c7b301be-5fb2-52f2-89c4-686602fb28ca">
#         <dcterms:identifier rdf:resource={"id":"c7b301be-5fb2-52f2-89c4-686602fb28ca","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ovg}/>
#         <skos:prefLabel xml:lang="nl">Onderwijsbibliotheek Vlaamse Gemeenschap</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7cc608a9-9bf6-56dc-a925-a5399d550540">
#         <skos:prefLabel xml:lang="nl">Collectie G. Walschap</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"7cc608a9-9bf6-56dc-a925-a5399d550540","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-gw}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/8a868d74-d950-53b4-b06e-135aeef4fe14">
#         <dcterms:identifier rdf:resource={"id":"8a868d74-d950-53b4-b06e-135aeef4fe14","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-dha}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie van de Uitgeverij Houtekiet</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/baddf1c1-e5f6-57b9-b03f-63d9487d71df">
#         <skos:prefLabel xml:lang="nl">Collectie Aegyptica-strips van Eddy Kerssens - doubletten</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"baddf1c1-e5f6-57b9-b03f-63d9487d71df","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-eksx}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/5408fefa-dd96-508d-947e-b5943f8982c9">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"5408fefa-dd96-508d-947e-b5943f8982c9","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-hoplanddepot3}/>
#         <dcterms:identifier rdf:resource={"id":"eb56ec30-af7b-5ded-9b7b-0f3eff7aa61e","value":"http://vocab.getty.edu/aat/300379012}/>
#         <skos:prefLabel xml:lang="nl">Niet gekend (rub-hoplanddepot3)</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/0de900ca-504e-5f9b-9986-ab59678ca0a4">
#         <skos:prefLabel xml:lang="nl">Fonds Karel Elebaers</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"0de900ca-504e-5f9b-9986-ab59678ca0a4","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ke}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/81bbd288-eb1d-5351-bb15-b9d8f8daaf56">
#         <skos:prefLabel xml:lang="nl">Artesis Plantijn Hogeschool-KC Digitaal Platform</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"81bbd288-eb1d-5351-bb15-b9d8f8daaf56","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ap-kc-dp}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/06b681f9-56b2-53e6-b2df-1fb5a566aed0">
#         <dcterms:identifier rdf:resource={"id":"06b681f9-56b2-53e6-b2df-1fb5a566aed0","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ssli}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie doubletten uit de Collectie van Stijn Streuvels aanwezig in het Lijsternest te Ingooigem</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/4a0221c9-e87f-5328-8586-b8108cd2d05f">
#         <skos:prefLabel xml:lang="nl">Bibliotheek Edward Frison</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"4a0221c9-e87f-5328-8586-b8108cd2d05f","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-ef}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/4c607c0d-bfb7-5169-8e5e-bb839400e786">
#         <dcterms:identifier rdf:resource={"id":"4c607c0d-bfb7-5169-8e5e-bb839400e786","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/mpm-nieuws}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Publicaties met nieuws</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/2d7b4b92-c9c8-5468-a99d-84798b7ec359">
#         <dcterms:identifier rdf:resource={"id":"eb56ec30-af7b-5ded-9b7b-0f3eff7aa61e","value":"http://vocab.getty.edu/aat/300379012}/>
#         <dcterms:identifier rdf:resource={"id":"2d7b4b92-c9c8-5468-a99d-84798b7ec359","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-balis}/>
#         <skos:prefLabel xml:lang="nl">Niet gekend (rub-balis)</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e2f0ce55-55bb-56ad-b6f9-c0538f586151">
#         <dcterms:identifier rdf:resource={"id":"e2f0ce55-55bb-56ad-b6f9-c0538f586151","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-eb}/>
#         <skos:prefLabel xml:lang="nl">Fonds EugÃ¨ne Baie</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/0fbdc32a-44cf-5650-8ec6-f83d807dad07">
#         <dcterms:identifier rdf:resource={"id":"0fbdc32a-44cf-5650-8ec6-f83d807dad07","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-shaw-miller}/>
#         <skos:prefLabel xml:lang="nl">Collectie Lindsey Shaw-Miller</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/6da240a7-557b-599b-9490-28d73223c23c">
#         <dcterms:identifier rdf:resource={"id":"6da240a7-557b-599b-9490-28d73223c23c","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-rg}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Fonds Robert Guiette</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e2efbd6e-4208-5578-8f48-3699cf6ee2ce">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Schenking</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"e2efbd6e-4208-5578-8f48-3699cf6ee2ce","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/rub-gift}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7637f30a-5bc6-5272-aef0-04190f8d6402">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Publicaties Henri Van Daele</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"7637f30a-5bc6-5272-aef0-04190f8d6402","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-hvd}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/61887b28-4e61-517e-a837-4974846deef8">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Veiling Emmanuel Hiel</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"61887b28-4e61-517e-a837-4974846deef8","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-veh}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/39fa5140-e283-5313-8eea-76096be1e43d">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"39fa5140-e283-5313-8eea-76096be1e43d","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-vh}/>
#         <skos:prefLabel xml:lang="nl">Collectie Museum Vleeshuis</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/59fb99f8-b832-549e-bbb1-5c86ef670f65">
#         <skos:prefLabel xml:lang="nl">Leerboeken UA-bibliotheek</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"59fb99f8-b832-549e-bbb1-5c86ef670f65","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-cstlb}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/1d27c923-5ba6-5380-b37c-20fe8108b468">
#         <skos:prefLabel xml:lang="nl">Fonds Fritz Sano</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"1d27c923-5ba6-5380-b37c-20fe8108b468","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-fs}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/5422115b-1dfe-5f9a-b724-9847824e8579">
#         <skos:prefLabel xml:lang="nl">Collectie van Ivo Michiels en Christiane Faes</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"5422115b-1dfe-5f9a-b724-9847824e8579","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-imcf}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/bc3158e6-7a75-5542-8414-fbc95e7bd5d2">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Fonds Jan de Roek</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"bc3158e6-7a75-5542-8414-fbc95e7bd5d2","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-jdr}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/7784a58c-06eb-54c7-9ab8-964343adeb1e">
#         <skos:prefLabel xml:lang="nl">Bibliotheek Poesjkin Centrum Antwerpen</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"7784a58c-06eb-54c7-9ab8-964343adeb1e","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-bpc}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/b034c6f8-c4c3-5a26-b784-a28c8940681d">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Collectie van Roger Charlier</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"b034c6f8-c4c3-5a26-b784-a28c8940681d","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-rc}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/42b5cfaa-226e-508f-a526-0aa51d76b7d5">
#         <skos:prefLabel xml:lang="nl">Fonds A.J. Strijmans</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"42b5cfaa-226e-508f-a526-0aa51d76b7d5","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-as}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/f38667db-a2d0-53b5-834f-dfd85018794a">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Fonds Antoinette Buckinx-Luyckx</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"f38667db-a2d0-53b5-834f-dfd85018794a","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-abl}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e53d0efd-68e1-58da-8768-671a1e9d60b1">
#         <dcterms:identifier rdf:resource={"id":"e53d0efd-68e1-58da-8768-671a1e9d60b1","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-dvr}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Depot Uitgeverij Vrijdag</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/984b6f19-ecdf-533a-a6be-968dfba8ddef">
#         <skos:prefLabel xml:lang="nl">Collectie Wim Gielen</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"984b6f19-ecdf-533a-a6be-968dfba8ddef","value":"https://data.antwerp.be/id/term/brocade-catalog/obj-sg/ehc-wg}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
# ...
#         <dcterms:identifier rdf:resource={"id":"2e4d96be-1433-5353-820f-8394b048f507","value":"https://data.antwerp.be/id/term/aspace-agents/agent-type/agent-corporate-entity}/>
#         <skos:prefLabel xml:lang="nl">Corporatieve entiteit</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/74f75990-c9c5-5076-b435-c3f3c9621890">
#         <dcterms:identifier rdf:resource={"id":"74f75990-c9c5-5076-b435-c3f3c9621890","value":"https://data.antwerp.be/id/term/aspace-agents/agent-type/agent-person}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Persoon</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"3943825c-a4c6-5269-9415-5e5710e0e802","value":"http://vocab.getty.edu/aat/300024979}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/9c7ece81-b4d8-54e7-92a2-8e5ea96844bd">
#         <skos:prefLabel xml:lang="nl">Familie</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"9c7ece81-b4d8-54e7-92a2-8e5ea96844bd","value":"https://data.antwerp.be/id/term/aspace-agents/agent-type/agent-family}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"797b2c2e-da9b-53dc-b34a-63993b8e0796","value":"http://vocab.getty.edu/aat/300055474}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/aspace-thesau/term-type">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/6b34dd5c-b744-537d-a31d-c7ee9659fa1c">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"6b34dd5c-b744-537d-a31d-c7ee9659fa1c","value":"https://data.antwerp.be/id/term/aspace-thesau/term-type/topicalgeographic}/>
#         <skos:prefLabel xml:lang="nl">Geografisch</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/a486708f-d9fa-5f9e-b55b-a260df484081">
#         <dcterms:identifier rdf:resource={"id":"a486708f-d9fa-5f9e-b55b-a260df484081","value":"https://data.antwerp.be/id/term/aspace-thesau/term-type/function}/>
#         <skos:prefLabel xml:lang="nl">Functie</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/e65cb952-db1c-5169-bc07-88970121d4b5">
#         <skos:prefLabel xml:lang="nl">Topisch</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"e65cb952-db1c-5169-bc07-88970121d4b5","value":"https://data.antwerp.be/id/term/aspace-thesau/term-type/topical}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/aspace-collect/role">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/2ad75d1c-9830-5b72-b073-0c299ea8548c">
#         <dcterms:identifier rdf:resource={"id":"2ad75d1c-9830-5b72-b073-0c299ea8548c","value":"https://data.antwerp.be/id/term/aspace-collect/role/creator}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Archiefvormer</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/brocade-catalog/lg-ty">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/d96dea55-70be-5ed6-a6ec-f4182f3f072e">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"d96dea55-70be-5ed6-a6ec-f4182f3f072e","value":"https://data.antwerp.be/id/term/brocade-catalog/lg-ty/bt}/>
#         <skos:prefLabel xml:lang="nl">Brontaal</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/39e6a0b1-6b4f-5fde-859a-3b605233b8c0">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Doeltaal</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"39e6a0b1-6b4f-5fde-859a-3b605233b8c0","value":"https://data.antwerp.be/id/term/brocade-catalog/lg-ty/dt}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/adlib-people/gender">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/0907ed7f-db27-53bb-ad04-e06663113964">
#         <skos:prefLabel xml:lang="nl">Vrouw</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"0907ed7f-db27-53bb-ad04-e06663113964","value":"https://data.antwerp.be/id/term/adlib-people/gender/female}/>
#         <dcterms:identifier rdf:resource={"id":"d6555921-a5c2-5774-aaa1-5ef69dba272c","value":"http://vocab.getty.edu/aat/300189557}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/d6c24b3f-ff38-5c50-bd9a-a9aa78dd3c87">
#         <dcterms:identifier rdf:resource={"id":"388186c0-57e8-58e4-b471-e3a18b4947c2","value":"http://vocab.getty.edu/aat/300189559}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"d6c24b3f-ff38-5c50-bd9a-a9aa78dd3c87","value":"https://data.antwerp.be/id/term/adlib-people/gender/male}/>
#         <skos:prefLabel xml:lang="nl">Man</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/df36c21b-f53a-50f7-9208-a2090afff034">
#         <dcterms:identifier rdf:resource={"id":"eb56ec30-af7b-5ded-9b7b-0f3eff7aa61e","value":"http://vocab.getty.edu/aat/300379012}/>
#         <skos:prefLabel xml:lang="nl">Niet gekend</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"df36c21b-f53a-50f7-9208-a2090afff034","value":"https://data.antwerp.be/id/term/adlib-people/gender/unknown}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/brocade">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/5411f647-e5ee-545a-bc16-65be1cc9b6e9">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Catalografie (brocade)</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"5411f647-e5ee-545a-bc16-65be1cc9b6e9","value":"https://data.antwerp.be/id/term/brocade-catalog}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/cb918d55-8fce-565a-980f-e74a5e87162c">
#         <dcterms:identifier rdf:resource={"id":"cb918d55-8fce-565a-980f-e74a5e87162c","value":"https://data.antwerp.be/id/term/brocade-authorities}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Term (brocade)</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/aspace-thesau">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/b0bee8de-d61e-5197-beeb-66eef17de323">
#         <dcterms:identifier rdf:resource={"id":"b0bee8de-d61e-5197-beeb-66eef17de323","value":"https://data.antwerp.be/id/term/aspace-thesau/term-type}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Term type</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"92da7022-b3a5-55d3-9a0c-b2d8253d9fbe","value":"http://vocab.getty.edu/aat/300055863}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/adlib-collect/content-person-name-type">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/d3ba514c-d754-5351-85b2-185396eba409">
#         <dcterms:identifier rdf:resource={"id":"d3ba514c-d754-5351-85b2-185396eba409","value":"https://data.antwerp.be/id/term/adlib-collect/content-person-name-type/person}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"3943825c-a4c6-5269-9415-5e5710e0e802","value":"http://vocab.getty.edu/aat/300024979}/>
#         <skos:prefLabel xml:lang="nl">Persoon</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/87d384a1-97a0-5203-8c7c-460e5b499206">
#         <dcterms:identifier rdf:resource={"id":"1cf32a6b-54a2-57f6-8483-9fb9ea4ceed2","value":"http://vocab.getty.edu/aat/300026004}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Instelling</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"87d384a1-97a0-5203-8c7c-460e5b499206","value":"https://data.antwerp.be/id/term/adlib-collect/content-person-name-type/inst}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/brocade-authorities/ta">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/0eaffd88-0e85-5673-b0cd-737fa44746c5">
#         <dcterms:identifier rdf:resource={"id":"0eaffd88-0e85-5673-b0cd-737fa44746c5","value":"https://data.antwerp.be/id/term/brocade-authorities/lg/u}/>
#         <skos:prefLabel xml:lang="nl">Niet gedefinieerd</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"eb56ec30-af7b-5ded-9b7b-0f3eff7aa61e","value":"http://vocab.getty.edu/aat/300379012}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/5bb78b34-2888-577a-bb6b-14da82559fdd">
#         <dcterms:identifier rdf:resource={"id":"5bb78b34-2888-577a-bb6b-14da82559fdd","value":"https://data.antwerp.be/id/term/brocade-authorities/lg/f}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"ba9d65aa-26fa-53b0-a10c-3294d48e09b2","value":"http://vocab.getty.edu/aat/300388306}/>
#         <skos:prefLabel xml:lang="nl">Frans</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/6f06ffd1-db8c-562d-8794-1ddf0e47482f">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"655b71df-152f-512f-90ac-9496ee987b56","value":"http://vocab.getty.edu/aat/300388277}/>
#         <skos:prefLabel xml:lang="nl">Engels</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"6f06ffd1-db8c-562d-8794-1ddf0e47482f","value":"https://data.antwerp.be/id/term/brocade-authorities/lg/e}/>
#       </skos:Concept>
#     </skos:narrower>
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/00c3837b-d11e-5547-bd21-a7e489687125">
#         <dcterms:identifier rdf:resource={"id":"00c3837b-d11e-5547-bd21-a7e489687125","value":"https://data.antwerp.be/id/term/brocade-authorities/lg/n}/>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <skos:prefLabel xml:lang="nl">Nederlands</skos:prefLabel>
#         <dcterms:identifier rdf:resource={"id":"8a591539-5048-5dde-b48d-260dd475d202","value":"http://vocab.getty.edu/aat/300388256}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/aspace-collect/setspec">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/53304e62-0b73-56c3-82b1-866218e80cd4">
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"53304e62-0b73-56c3-82b1-866218e80cd4","value":"https://data.antwerp.be/id/term/aspace-collect/setspec/archives}/>
#         <skos:prefLabel xml:lang="nl">Archiefeenheid</skos:prefLabel>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/adlib-collect/collection">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/d46fcf23-a902-5d42-a6fa-47119afad10a">
#         <skos:prefLabel xml:lang="nl">Agent Collection type (adlib)</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#         <dcterms:identifier rdf:resource={"id":"d46fcf23-a902-5d42-a6fa-47119afad10a","value":"https://data.antwerp.be/id/term/adlib-collect/content-person-name-type}/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <rdf:Description rdf:about="https://data.antwerp.be/id/term/aspace-collect/restrictions-apply">
#     <skos:narrower>
#       <skos:Concept rdf:about="https://localhost:8000/33580dea-91fe-519b-8eb1-c1ab55d5f144">
#         <dcterms:identifier rdf:resource={"id":"33580dea-91fe-519b-8eb1-c1ab55d5f144","value":"https://data.antwerp.be/id/term/aspace-collect/restrictions-apply/false}/>
#         <skos:prefLabel xml:lang="nl">False</skos:prefLabel>
#         <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#       </skos:Concept>
#     </skos:narrower>
#   </rdf:Description>
#   <skos:Concept rdf:about="https://localhost:8000/501425ba-c7f4-507c-b39d-996b3507089d">
#     <dcterms:identifier rdf:resource={"id":"501425ba-c7f4-507c-b39d-996b3507089d","value":"https://data.antwerp.be/id/term/aspace}/>
#     <skos:inScheme>
#       <skos:ConceptScheme rdf:about="https://data.antwerp.be/id/term/Datahub">
#         <skos:hasTopConcept rdf:resource="https://localhost:8000/e42136b3-d5fe-59f1-8a76-d9b307608dc1"/>
#         <skos:hasTopConcept rdf:resource="https://localhost:8000/ff36953c-8a31-544a-b883-608a01d05dd1"/>
#         <dcterms:title xml:lang="nl">Datahub</dcterms:title>
#         <skos:hasTopConcept rdf:resource="https://localhost:8000/50ec0d6a-258d-5ef6-81f0-4a775d906d53"/>
#         <skos:hasTopConcept rdf:resource="https://localhost:8000/501425ba-c7f4-507c-b39d-996b3507089d"/>
#       </skos:ConceptScheme>
#     </skos:inScheme>
#     <skos:prefLabel xml:lang="nl">Aspace</skos:prefLabel>
#   </skos:Concept>
#   <skos:Concept rdf:about="https://localhost:8000/ff36953c-8a31-544a-b883-608a01d05dd1">
#     <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#     <dcterms:identifier rdf:resource={"id":"ff36953c-8a31-544a-b883-608a01d05dd1","value":"https://data.antwerp.be/id/term/brocade}/>
#     <skos:prefLabel xml:lang="nl">Brocade</skos:prefLabel>
#   </skos:Concept>
#   <skos:Concept rdf:about="https://localhost:8000/50ec0d6a-258d-5ef6-81f0-4a775d906d53">
#     <dcterms:identifier rdf:resource={"id":"50ec0d6a-258d-5ef6-81f0-4a775d906d53","value":"https://data.antwerp.be/id/term/adlib-collect}/>
#     <skos:prefLabel xml:lang="nl">Adlib</skos:prefLabel>
#     <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#   </skos:Concept>
#   <skos:Concept rdf:about="https://localhost:8000/e42136b3-d5fe-59f1-8a76-d9b307608dc1">
#     <skos:inScheme rdf:resource="https://data.antwerp.be/id/term/Datahub"/>
#     <dcterms:identifier rdf:resource={"id":"e42136b3-d5fe-59f1-8a76-d9b307608dc1","value":"https://data.antwerp.be/id/def/}/>
#     <skos:prefLabel xml:lang="nl">Antwerp Definitions</skos:prefLabel>
#   </skos:Concept>
# </rdf:RDF>
